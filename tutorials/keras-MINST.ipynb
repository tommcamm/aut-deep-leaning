# %% [markdown]
# # Keras MINST example
#
# Took from the official "Code examples" repository of Keras, https://keras.io/examples/vision/mnist_convnet/, Credits to [fchollet](https://twitter.com/fchollet).

# %%
# Setup - Code imports
import numpy as np
import keras
import tensorflow as tf
from keras import layers

# %%
from keras import backend as K

# Check keras backend and GPU avail
print(f"Current keras backend: {K.backend()}")
print(f"GPU avail: {tf.config.list_physical_devices('GPU')}")
print(f"CUDA support: {tf.test.is_built_with_cuda()}")
# Out:
# Current keras backend: tensorflow
# GPU avail: []
# CUDA support: False

# %% [markdown]
# ## Data preparation
#
# This example uses the MINST dataset to recognize digits, the dataset will be loaded using the provided function from *Keras*.

# %%
# Model / Data parameters
num_classes = 10
input_shape = (28, 28, 1)

# Load the data and split between train and test - Done automatically by keras
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255

x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
print("x_train shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")


# covert class vectors to binary class matches
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %% [markdown]
# ## Model definition

# %%
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation='softmax'),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │        16,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,826 (136.04 KB)
#  Trainable params: 34,826 (136.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Model training

# %%
batch_size = 128 # Number of samples that will be propagated
epochs = 15 # How many times we will train on the train set

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# Epoch 1/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7686 - loss: 0.7574 - val_accuracy: 0.9788 - val_loss: 0.0787
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9637 - loss: 0.1179 - val_accuracy: 0.9847 - val_loss: 0.0562
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9743 - loss: 0.0827 - val_accuracy: 0.9875 - val_loss: 0.0441
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9767 - loss: 0.0723 - val_accuracy: 0.9887 - val_loss: 0.0407
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9815 - loss: 0.0622 - val_accuracy: 0.9898 - val_loss: 0.0364
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9820 - loss: 0.0580 - val_accuracy: 0.9898 - val_loss: 0.0362
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9828 - loss: 0.0538 - val_accuracy: 0.9902 - val_loss: 0.0351
# Epoch 8/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9856 - loss: 0.0458 - val_accuracy: 0.9898 - val_loss: 0.0316
# Epoch 9/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9872 - loss: 0.0421 - val_accuracy: 0.9917 - val_loss: 0.0289
# Epoch 10/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9879 - loss: 0.0387 - val_accuracy: 0.9913 - val_loss: 0.0304
# Epoch 11/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9878 - loss: 0.0370 - val_accuracy: 0.9920 - val_loss: 0.0272
# Epoch 12/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9881 - loss: 0.0350 - val_accuracy: 0.9922 - val_loss: 0.0276
# Epoch 13/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9886 - loss: 0.0342 - val_accuracy: 0.9928 - val_loss: 0.0279
# Epoch 14/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9893 - loss: 0.0336 - val_accuracy: 0.9930 - val_loss: 0.0279
# Epoch 15/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9894 - loss: 0.0327 - val_accuracy: 0.9930 - val_loss: 0.0284

# %% [markdown]
# ## Model evaluation

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.022628851234912872
# Test accuracy: 0.9923999905586243

# %%
from matplotlib import pyplot as plt
from sklearn.metrics import multilabel_confusion_matrix
import seaborn as sns

# My own evaluations

y_pred = model.predict(x_test)
y_pred = np.where(y_pred > 0.5, 1,0) # Convert to classification 0 or 1

conf = multilabel_confusion_matrix(y_test, y_pred)

num_labels = conf.shape[0]
rows = (num_labels + 1) // 2  # Calculate the number of rows needed (with up to 2 matrices per row)

fig, axes = plt.subplots(rows, 2, figsize=(10, rows*4))  # Adjust the size accordingly

for i, matrix in enumerate(conf):
    ax = axes[i // 2, i % 2]  # Determine the row and column index
    sns.heatmap(matrix, annot=True, fmt='d', cmap='Blues', ax=ax)
    ax.set_title(f'Number {i} Confusion Matrix')
    ax.set_xlabel('Predicted labels')
    ax.set_ylabel('True labels')
    ax.set_xticklabels(['Negative', 'Positive'])
    ax.set_yticklabels(['Negative', 'Positive'])

# If the number of labels is odd, hide the last subplot (if unused)
if num_labels % 2 != 0:
    axes[-1, -1].axis('off')

plt.tight_layout()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
